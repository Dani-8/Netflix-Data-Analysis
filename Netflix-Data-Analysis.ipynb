# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix1.csv")

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df["date_added"] = pd.to_datetime(df["date_added"])
df["date_added"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 686.8+ KB

# %%
df.describe(include="all")
# Out:
#        show_id   type  title   director        country  \
# count     8790   8790   8790       8790           8790
# unique    8790      2   8787       4528             86
# top      s8786  Movie  9-Feb  Not Given  United States
# freq         1   6126      2       2588           3240
# mean       NaN    NaN    NaN        NaN            NaN
# min        NaN    NaN    NaN        NaN            NaN
# 25%        NaN    NaN    NaN        NaN            NaN
# 50%        NaN    NaN    NaN        NaN            NaN
# 75%        NaN    NaN    NaN        NaN            NaN
# max        NaN    NaN    NaN        NaN            NaN
# std        NaN    NaN    NaN        NaN            NaN
#
#                            date_added  release_year rating  duration  \
# count                            8790   8790.000000   8790      8790
# unique                            NaN           NaN     14       220
# top                               NaN           NaN  TV-MA  1 Season
# ...

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
types = df["type"].value_counts().reset_index()
types
# Out:
#       type  count
# 0    Movie   6126
# 1  TV Show   2664

# %%
countries = df["country"].value_counts().reset_index()
countries
# Out:
#            country  count
# 0    United States   3240
# 1            India   1057
# 2   United Kingdom    638
# 3         Pakistan    421
# 4        Not Given    287
# ..             ...    ...
# 81      Luxembourg      1
# 82         Senegal      1
# 83         Belarus      1
# 84     Puerto Rico      1
# 85          Cyprus      1
#
# [86 rows x 2 columns]

# %%
df.groupby("type")["country"].value_counts().reset_index()
# Out:
#         type               country  count
# 0      Movie         United States   2395
# 1      Movie                 India    976
# 2      Movie        United Kingdom    387
# 3      Movie             Not Given    257
# 4      Movie                Canada    187
# ..       ...                   ...    ...
# 133  TV Show           Puerto Rico      1
# 134  TV Show               Senegal      1
# 135  TV Show           Switzerland      1
# 136  TV Show  United Arab Emirates      1
# 137  TV Show               Uruguay      1
#
# [138 rows x 3 columns]

# %%
df.groupby("type")["director"].value_counts().reset_index()
# Out:
#          type                              director  count
# 0       Movie                             Not Given    173
# 1       Movie                         Rajiv Chilaka     19
# 2       Movie                Raúl Campos, Jan Suter     18
# 3       Movie                           Suhas Kadav     16
# 4       Movie                          Marcus Raboy     15
# ...       ...                                   ...    ...
# 4576  TV Show                   Vijay S. Bhanushali      1
# 4577  TV Show  Vikramaditya Motwane, Anurag Kashyap      1
# 4578  TV Show                        Wouter Bouvijn      1
# 4579  TV Show                         Yasuhiro Irie      1
# 4580  TV Show                          Ziad Doueiri      1
#
# [4581 rows x 3 columns]

# %%
director = df[df["director"] != "Not Given"][["type", "director"]].value_counts().sort_values(ascending=False).reset_index()
director
# Out:
#          type                              director  count
# 0       Movie                         Rajiv Chilaka     19
# 1       Movie                Raúl Campos, Jan Suter     18
# 2       Movie                           Suhas Kadav     16
# 3       Movie                          Marcus Raboy     15
# 4     TV Show                   Alastair Fothergill     14
# ...       ...                                   ...    ...
# 4574  TV Show                   Vijay S. Bhanushali      1
# 4575  TV Show  Vikramaditya Motwane, Anurag Kashyap      1
# 4576  TV Show                        Wouter Bouvijn      1
# 4577  TV Show                         Yasuhiro Irie      1
# 4578    Movie                         Thomas Stuber      1
#
# [4579 rows x 3 columns]

# %%
top_10_director = director.head(10)
top_10_director
# Out:
#       type                director  count
# 0    Movie           Rajiv Chilaka     19
# 1    Movie  Raúl Campos, Jan Suter     18
# 2    Movie             Suhas Kadav     16
# 3    Movie            Marcus Raboy     15
# 4  TV Show     Alastair Fothergill     14
# 5    Movie               Jay Karas     14
# 6    Movie     Cathy Garcia-Molina     13
# 7    Movie         Martin Scorsese     12
# 8    Movie             Jay Chapman     12
# 9    Movie         Youssef Chahine     12

# %%
top_10_movie_director = director[director["type"] == "Movie"].head(10)
top_10_movie_director
# Out:
#      type                director  count
# 0   Movie           Rajiv Chilaka     19
# 1   Movie  Raúl Campos, Jan Suter     18
# 2   Movie             Suhas Kadav     16
# 3   Movie            Marcus Raboy     15
# 5   Movie               Jay Karas     14
# 6   Movie     Cathy Garcia-Molina     13
# 7   Movie         Martin Scorsese     12
# 8   Movie             Jay Chapman     12
# 9   Movie         Youssef Chahine     12
# 10  Movie        Steven Spielberg     11

# %%
top_10_TVShow_director = director[director["type"] == "TV Show"].head(10)
top_10_TVShow_director
# Out:
#          type                           director  count
# 4     TV Show                Alastair Fothergill     14
# 82    TV Show       Mark Thornton, Todd Kauffman      5
# 234   TV Show                        Stan Lathan      3
# 835   TV Show                        Hsu Fu-chun      2
# 836   TV Show                     Iginio Straffi      2
# 837   TV Show                          Ken Burns      2
# 839   TV Show                    Rob Seidenglanz      2
# 840   TV Show                        Shin Won-ho      2
# 871   TV Show                          Sion Sono      1
# 2292  TV Show  Thierry Demaizière, Alban Teurlai      1

# %%
df["country"].unique()
# Out:
# array(['United States', 'France', 'Brazil', 'United Kingdom', 'India',
#        'Germany', 'Pakistan', 'Not Given', 'China', 'South Africa',
#        'Japan', 'Nigeria', 'Spain', 'Philippines', 'Australia',
#        'Argentina', 'Canada', 'Hong Kong', 'Italy', 'New Zealand',
#        'Egypt', 'Colombia', 'Mexico', 'Belgium', 'Switzerland', 'Taiwan',
#        'Bulgaria', 'Poland', 'South Korea', 'Saudi Arabia', 'Thailand',
#        'Indonesia', 'Kuwait', 'Malaysia', 'Vietnam', 'Lebanon', 'Romania',
#        'Syria', 'United Arab Emirates', 'Sweden', 'Mauritius', 'Austria',
#        'Turkey', 'Czech Republic', 'Cameroon', 'Netherlands', 'Ireland',
#        'Russia', 'Kenya', 'Chile', 'Uruguay', 'Bangladesh', 'Portugal',
#        'Hungary', 'Norway', 'Singapore', 'Iceland', 'Serbia', 'Namibia',
#        'Peru', 'Mozambique', 'Ghana', 'Zimbabwe', 'Israel', 'Finland',
#        'Denmark', 'Paraguay', 'Cambodia', 'Georgia', 'Soviet Union',
# ...

# %%
df["country"].nunique()
# Out:
# 86

# %%
df["director"].nunique()
# Out:
# 4528

# %%
df["release_year"].unique()
# Out:
# array([2020, 2021, 1993, 2019, 2013, 2014, 2018, 1998, 2010, 2017, 1997,
#        1996, 1975, 1978, 1983, 1987, 2012, 2001, 2002, 2003, 2004, 2011,
#        2008, 2009, 2007, 2005, 2006, 2016, 1994, 2015, 1982, 1989, 1990,
#        1991, 1999, 1986, 1984, 1980, 1961, 2000, 1995, 1985, 1925, 1992,
#        1976, 1959, 1988, 1981, 1972, 1964, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1960, 1974, 1966, 1971, 1962, 1969, 1977, 1967, 1968,
#        1965, 1945, 1946, 1942, 1955, 1944, 1947, 1943])

# %%
df["release_year"].value_counts().reset_index().head(10)
# Out:
#    release_year  count
# 0          2018   1146
# 1          2019   1030
# 2          2017   1030
# 3          2020    953
# 4          2016    901
# 5          2021    592
# 6          2015    555
# 7          2014    352
# 8          2013    286
# 9          2012    236

# %%
countries = df[df["country"] != "Not Given"][["type", "country"]].value_counts().reset_index()
countries
# Out:
#         type               country  count
# 0      Movie         United States   2395
# 1      Movie                 India    976
# 2    TV Show         United States    845
# 3      Movie        United Kingdom    387
# 4    TV Show              Pakistan    350
# ..       ...                   ...    ...
# 131  TV Show             Mauritius      1
# 132  TV Show           Switzerland      1
# 133  TV Show               Senegal      1
# 134  TV Show  United Arab Emirates      1
# 135  TV Show               Uruguay      1
#
# [136 rows x 3 columns]

# %%
top_10_countries = countries.head(10)
top_10_countries
# Out:
#       type         country  count
# 0    Movie   United States   2395
# 1    Movie           India    976
# 2  TV Show   United States    845
# 3    Movie  United Kingdom    387
# 4  TV Show        Pakistan    350
# 5  TV Show  United Kingdom    251
# 6    Movie          Canada    187
# 7  TV Show           Japan    172
# 8  TV Show     South Korea    165
# 9    Movie          France    148

# %%
top_10_movie_countries = countries[countries["type"] == "Movie"].head(10)
top_10_movie_countries
# Out:
#      type         country  count
# 0   Movie   United States   2395
# 1   Movie           India    976
# 3   Movie  United Kingdom    387
# 6   Movie          Canada    187
# 9   Movie          France    148
# 10  Movie           Spain    129
# 11  Movie           Egypt    109
# 12  Movie         Nigeria     96
# 13  Movie          Mexico     90
# 14  Movie           Japan     87

# %%
top_10_TV_Show_countries = countries[countries["type"] == "TV Show"].head(10)
top_10_TV_Show_countries
# Out:
#        type         country  count
# 2   TV Show   United States    845
# 4   TV Show        Pakistan    350
# 5   TV Show  United Kingdom    251
# 7   TV Show           Japan    172
# 8   TV Show     South Korea    165
# 16  TV Show          Canada     84
# 18  TV Show           India     81
# 23  TV Show          Taiwan     71
# 24  TV Show          France     65
# 29  TV Show       Australia     53

# %%
release_years = df["release_year"].value_counts().reset_index()
release_years
# Out:
#     release_year  count
# 0           2018   1146
# 1           2019   1030
# 2           2017   1030
# 3           2020    953
# 4           2016    901
# ..           ...    ...
# 69          1961      1
# 70          1959      1
# 71          1925      1
# 72          1966      1
# 73          1947      1
#
# [74 rows x 2 columns]

# %%
top_10_releases_years = release_years.sort_values(by="count", ascending=False).head(10)
top_10_releases_years
# Out:
#    release_year  count
# 0          2018   1146
# 1          2019   1030
# 2          2017   1030
# 3          2020    953
# 4          2016    901
# 5          2021    592
# 6          2015    555
# 7          2014    352
# 8          2013    286
# 9          2012    236

# %%
df["duration"].unique()
# Out:
# array(['90 min', '1 Season', '91 min', '125 min', '9 Seasons', '104 min',
#        '87 min', '127 min', '76 min', '71 min', '131 min', '39 min',
#        '36 min', '34 min', '35 min', '46 min', '67 min', '65 min',
#        '61 min', '166 min', '103 min', '97 min', '106 min', '2 Seasons',
#        '4 Seasons', '147 min', '94 min', '161 min', '111 min', '110 min',
#        '105 min', '96 min', '124 min', '116 min', '98 min', '115 min',
#        '122 min', '55 min', '99 min', '88 min', '100 min', '6 Seasons',
#        '3 Seasons', '23 min', '102 min', '93 min', '95 min', '85 min',
#        '83 min', '182 min', '5 Seasons', '92 min', '84 min', '48 min',
#        '145 min', '119 min', '80 min', '128 min', '143 min', '273 min',
#        '117 min', '114 min', '118 min', '108 min', '37 min', '121 min',
#        '63 min', '142 min', '113 min', '154 min', '120 min', '82 min',
#        '109 min', '101 min', '86 min', '77 min', '229 min', '15 min',
# ...

# %%
df["duration"].nunique()
# Out:
# 220

# %%
durations = df.groupby(["type", "duration"])["duration"].value_counts().sort_values(ascending=False).reset_index()
durations
# Out:
#         type    duration  count
# 0    TV Show    1 Season   1791
# 1    TV Show   2 Seasons    421
# 2    TV Show   3 Seasons    198
# 3      Movie      90 min    152
# 4      Movie      93 min    146
# ..       ...         ...    ...
# 215    Movie     228 min      1
# 216    Movie       8 min      1
# 217    Movie       9 min      1
# 218  TV Show  17 Seasons      1
# 219  TV Show  11 Seasons      1
#
# [220 rows x 3 columns]

# %%
top_10_duration = durations.head(10)
top_10_duration
# Out:
#       type   duration  count
# 0  TV Show   1 Season   1791
# 1  TV Show  2 Seasons    421
# 2  TV Show  3 Seasons    198
# 3    Movie     90 min    152
# 4    Movie     93 min    146
# 5    Movie     97 min    146
# 6    Movie     94 min    146
# 7    Movie     91 min    144
# 8    Movie     95 min    137
# 9    Movie     96 min    130

# %%
df["rating"].nunique()
# Out:
# 14

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', 'TV-14', 'TV-Y7', 'TV-Y', 'PG', 'TV-G',
#        'R', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
rating = df.groupby(["type", "rating"])["rating"].value_counts().sort_values(ascending=False).reset_index()
rating
# Out:
#        type    rating  count
# 0     Movie     TV-MA   2062
# 1     Movie     TV-14   1427
# 2   TV Show     TV-MA   1143
# 3     Movie         R    797
# 4   TV Show     TV-14    730
# 5     Movie     TV-PG    540
# 6     Movie     PG-13    490
# 7   TV Show     TV-PG    321
# 8     Movie        PG    287
# 9   TV Show     TV-Y7    194
# 10  TV Show      TV-Y    175
# 11    Movie     TV-Y7    139
# 12    Movie      TV-Y    131
# 13    Movie      TV-G    126
# 14  TV Show      TV-G     94
# 15    Movie        NR     75
# 16    Movie         G     41
# 17    Movie  TV-Y7-FV      5
# 18  TV Show        NR      4
# 19    Movie     NC-17      3
# 20    Movie        UR      3
# 21  TV Show         R      2
# 22  TV Show  TV-Y7-FV      1

# %%
top_10_rating =  rating.head(10)
top_10_rating
# Out:
#       type rating  count
# 0    Movie  TV-MA   2062
# 1    Movie  TV-14   1427
# 2  TV Show  TV-MA   1143
# 3    Movie      R    797
# 4  TV Show  TV-14    730
# 5    Movie  TV-PG    540
# 6    Movie  PG-13    490
# 7  TV Show  TV-PG    321
# 8    Movie     PG    287
# 9  TV Show  TV-Y7    194

# %%
genres = df.groupby(["listed_in", "type"])["listed_in"].value_counts().reset_index()
genres
# Out:
#                                              listed_in     type  count
# 0                                   Action & Adventure    Movie    128
# 1                   Action & Adventure, Anime Features    Movie      1
# 2    Action & Adventure, Anime Features, Children &...    Movie      4
# 3    Action & Adventure, Anime Features, Classic Mo...    Movie      2
# 4    Action & Adventure, Anime Features, Horror Movies    Movie      1
# ..                                                 ...      ...    ...
# 508             TV Horror, TV Mysteries, Teen TV Shows  TV Show      1
# 509                           TV Horror, Teen TV Shows  TV Show      2
# 510                  TV Sci-Fi & Fantasy, TV Thrillers  TV Show      1
# 511                                           TV Shows  TV Show     16
# 512                                          Thrillers    Movie     65
#
# [513 rows x 3 columns]

# %%
top_10_genres = genres.sort_values(by="count", ascending = False).head(10)
top_10_genres
# Out:
#                                             listed_in     type  count
# 325                      Dramas, International Movies    Movie    362
# 273                                     Documentaries    Movie    359
# 469                                   Stand-Up Comedy    Movie    334
# 199            Comedies, Dramas, International Movies    Movie    274
# 318  Dramas, Independent Movies, International Movies    Movie    252
# 421                                          Kids' TV  TV Show    219
# 120                          Children & Family Movies    Movie    215
# 124                Children & Family Movies, Comedies    Movie    201
# 280               Documentaries, International Movies    Movie    186
# 328     Dramas, International Movies, Romantic Movies    Movie    180

# %%
genres_countries = (
    df[df[["listed_in", "type", "country"]] != "Not Given"]
      .groupby(["listed_in", "type", "country"])["listed_in"]
      .value_counts()
      .reset_index()
)

genres_countries
# Out:
#                listed_in   type         country  count
# 0     Action & Adventure  Movie       Australia      1
# 1     Action & Adventure  Movie        Bulgaria      1
# 2     Action & Adventure  Movie          Canada      6
# 3     Action & Adventure  Movie           China      1
# 4     Action & Adventure  Movie          France      3
# ...                  ...    ...             ...    ...
# 1942           Thrillers  Movie          France      1
# 1943           Thrillers  Movie       Singapore      1
# 1944           Thrillers  Movie           Spain      1
# 1945           Thrillers  Movie  United Kingdom      6
# 1946           Thrillers  Movie   United States     50
#
# [1947 rows x 4 columns]

# %%
genres_countries.sort_values(by="count",ascending=False).head(10)
# Out:
#                                              listed_in     type  \
# 870                                      Documentaries    Movie
# 1871                                   Stand-Up Comedy    Movie
# 542             Comedies, Dramas, International Movies    Movie
# 354                 Children & Family Movies, Comedies    Movie
# 1145                      Dramas, International Movies    Movie
# 1084  Dramas, Independent Movies, International Movies    Movie
# 1744                                          Kids' TV  TV Show
# 331                           Children & Family Movies    Movie
# 1045                                            Dramas    Movie
# 493                                           Comedies    Movie
#
#             country  count
# 870   United States    269
# 1871  United States    216
# 542           India    124
# 354   United States    122
# 1145          India    122
# 1084          India    118
# 1744  United States    107
# 331   United States    104
# ...

# %%
# For each country, pick the genre with max count
top_genre_per_country = genres_countries.loc[genres_countries.groupby("country")["count"].idxmax()]
top_genre_per_country
# Out:
#                                               listed_in     type  \
# 1126                       Dramas, International Movies    Movie
# 1001  Docuseries, International TV Shows, Science & ...  TV Show
# 1128                       Dramas, International Movies    Movie
# 1069   Dramas, Independent Movies, International Movies    Movie
# 300             British TV Shows, Kids' TV, TV Comedies  TV Show
# ...                                                 ...      ...
# 566              Comedies, Dramas, International Movies    Movie
# 917                 Documentaries, International Movies    Movie
# 89    Action & Adventure, Comedies, International Mo...    Movie
# 918                 Documentaries, International Movies    Movie
# 694     Comedies, International Movies, Romantic Movies    Movie
#
#            country  count
# 1126     Argentina      9
# 1001     Australia      6
# 1128       Austria      2
# 1069    Bangladesh      2
# 300        Belarus      1
# ...

# %%
chk_one_country = genres_countries[genres_countries["country"] == "United States"]
chk_one_country
# Out:
#                                               listed_in     type  \
# 13                                   Action & Adventure    Movie
# 15    Action & Adventure, Anime Features, Children &...    Movie
# 21    Action & Adventure, Anime Features, Sci-Fi & F...    Movie
# 23         Action & Adventure, Children & Family Movies    Movie
# 24    Action & Adventure, Children & Family Movies, ...    Movie
# ...                                                 ...      ...
# 1931              TV Horror, TV Mysteries, TV Thrillers  TV Show
# 1932             TV Horror, TV Mysteries, Teen TV Shows  TV Show
# 1933                           TV Horror, Teen TV Shows  TV Show
# 1939                                           TV Shows  TV Show
# 1946                                          Thrillers    Movie
#
#             country  count
# 13    United States     86
# 15    United States      1
# 21    United States      1
# 23    United States      1
# 24    United States      4
# ...

# %%
chk_one_country["listed_in"].unique()
# Out:
# array(['Action & Adventure',
#        'Action & Adventure, Anime Features, Children & Family Movies',
#        'Action & Adventure, Anime Features, Sci-Fi & Fantasy',
#        'Action & Adventure, Children & Family Movies',
#        'Action & Adventure, Children & Family Movies, Classic Movies',
#        'Action & Adventure, Children & Family Movies, Comedies',
#        'Action & Adventure, Children & Family Movies, Dramas',
#        'Action & Adventure, Children & Family Movies, Independent Movies',
#        'Action & Adventure, Children & Family Movies, Sci-Fi & Fantasy',
#        'Action & Adventure, Classic Movies',
#        'Action & Adventure, Classic Movies, Comedies',
#        'Action & Adventure, Classic Movies, Cult Movies',
#        'Action & Adventure, Classic Movies, Dramas',
#        'Action & Adventure, Classic Movies, Sci-Fi & Fantasy',
#        'Action & Adventure, Comedies',
#        'Action & Adventure, Comedies, Cult Movies',
# ...

# %% [markdown]
# ## PLOTTING

# %%
plt.figure(figsize=[20,10])

types.plot.pie(y="count", labels=["Movies", "TV Show"], autopct='%1.1f%%', explode=[0,0.05], shadow=True)
plt.axis('equal')
plt.title("Types")

plt.show()

# %%
plt.figure(figsize=[20,10])

sns.barplot(x="director", y="count", data=top_10_director, hue="director", palette="muted")
plt.title("Top 10 Director")
plt.xlabel("Directors")
plt.ylabel("Number of Movies/Tv Show")

plt.show()

# %%
plt.figure(figsize=[20,10])

sns.barplot(x="director", y="count", data=top_10_movie_director,hue="director", palette="muted", legend=True)
plt.title("Top 10 Movies Director")
plt.xlabel("Directors")
plt.ylabel("Number of Movies")

plt.show()

# %%
plt.figure(figsize=[20,8])

sns.barplot(x="director", y="count", data=top_10_TVShow_director, hue="director", palette="muted", legend=True)
plt.title("Top 10 TV Show Director")

plt.xlabel("Directors")
plt.ylabel("Number of TV Show")

plt.show()

# %%
plt.figure(figsize=[20,10])

ax = sns.barplot(data=top_10_countries, x="country", y="count", hue="type", palette="Set1", legend=True)

# Add counts as labels
for container in ax.containers:
    ax.bar_label(container, fontsize=12)

    
plt.title("Top 10 Countries")
plt.xlabel("Countries")
plt.ylabel("No of Movies")
plt.show()

# %%
plt.title("2012-2022")

sns.lineplot(data=top_10_releases_years, x="release_year", y="count", legend=True, markers=True)
sns.set_style("darkgrid")

plt.xticks(top_10_releases_years['release_year'])
plt.xlabel("years")
plt.show()

# %%
plt.figure(figsize=[15,6])
sns.barplot(data=top_10_rating, x="rating", y="count", hue="type", palette="Set1")

plt.title("Top 10 Rating")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=[20,8])
sns.barplot(data=top_10_genres, x="listed_in", y="count", hue="type", palette="Set2")

plt.title("Top 10 Genres")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=[20,7])

plt.pie(data=top_10_duration.head(5), x="count", labels="duration", autopct="%1.1f%%", explode=[0.05,0,0,0,0])
plt.title("Top 5 Durations")
plt.legend(top_10_duration["duration"])
plt.show()
